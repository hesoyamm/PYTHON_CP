# %% [markdown]
# Write an efficient algorithm that searches for a value in an m x n matrix. This matrix has the following properties:
#
# Integers in each row are sorted from left to right.
# The first integer of each row is greater than the last integer of the previous row.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Input: matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]],
#
# target = 3
#
#
# Output: true

# %% [markdown]
# from bisect import bisect_left
# def find(ele,mat):
# while(i!=len(mat)):
#     if(ele>mat[0][0]and ele<mat[0][len(matrix)]):
#         i=bisect_left(matrix[0],ele)
#             if i:
#                 return true
#             else:
#                 return false
#     elif(ele>mat[i][0] and ele<mat[i][len(matrix)]):
#          i=bisect_left(matrix[0],ele)
#             if i:
#                 return true
#             else:
#                 return false
#     elif(ele>mat[i][0] and ele<mat[i][len(matrix)]):
#          i=bisect_left(matrix[0],ele)
#             if i:
#                 return true
#             else:
#                 return false
#         i=i+1

# %%
#LEET CODE CRAZY SOLUTION
from bisect import bisect_left
class Solution:
    def searchMatrix(self, matrix: List[List[int]], target: int) -> bool:
        return bool(matrix) and target in matrix[bisect.bisect(matrix, [target + 0.5]) - 1]
# Out:
# 7
